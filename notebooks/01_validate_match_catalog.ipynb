# %% [markdown]
# # Validate Match Catalog
#
# Quick checks for the Stage 1 match catalog.

# %%
from pathlib import Path
import pandas as pd

catalog_path = Path('../data/silver/matches_catalog/matches_catalog.parquet')
df = pd.read_parquet(catalog_path)
df.head()

# %%
df['map_name'].value_counts(dropna=False)

# %%
df['opponent'].value_counts(dropna=False)

# %%
df['validation_status'].value_counts(dropna=False)

# %%
dates = pd.to_datetime(df['match_date'], errors='coerce')
dates.min(), dates.max()
