# %% [markdown]
# # Stage 8.10 -- Vitality Multi-Map Tactical EDA

# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
BASE = Path('../data/gold/analysis/multi_map_tactical_eda')
def load(name):
    return pd.read_parquet(BASE / f'{name}.parquet')

# %% [markdown]
# ## Scope

# %%
scope = load('multi_map_eda_scope_inventory')
display(scope)
scope.plot.bar(x='map_id', y=['t_rounds','planted_t_rounds','no_plant_t_rounds'], figsize=(8,4))
plt.tight_layout()

# %% [markdown]
# ## Quality Status

# %%
display(load('multi_map_tactical_eda_audit'))
display(load('multi_map_eda_read_only_audit'))

# %% [markdown]
# ## Plant Distribution

# %%
plant = load('plant_site_distribution')
display(plant)
plant.plot.bar(x='map_id', y=['a_share','b_share'], figsize=(7,4))
plt.tight_layout()

# %% [markdown]
# ## Utility Inventory

# %%
utility_inv = load('utility_inventory_comparison')
display(utility_inv.head(30))

# %% [markdown]
# ## Utility Timing

# %%
utility = load('utility_timing_comparison')
display(utility.sort_values('cliffs_delta', key=lambda s: s.abs(), ascending=False).head(25))

# %% [markdown]
# ## Semantic Progression

# %%
semantic = load('semantic_control_profile')
display(semantic.head(30))

# %% [markdown]
# ## Team Structure

# %%
structure = load('team_structure_comparison')
display(structure.head(30))

# %% [markdown]
# ## A/B Comparisons

# %%
within = load('within_map_site_comparison')
display(within.sort_values('cliffs_delta', key=lambda s: s.abs(), ascending=False).head(30))

# %% [markdown]
# ## Planted vs No-Plant

# %%
pnp = load('plant_vs_no_plant_comparison')
display(pnp.sort_values('cliffs_delta', key=lambda s: s.abs(), ascending=False).head(30))

# %% [markdown]
# ## Demo Stability

# %%
stability = load('multi_map_demo_stability')
display(stability.head(30))

# %% [markdown]
# ## Ranked Findings

# %%
ranked = load('multi_map_ranked_findings')
display(ranked)

# %% [markdown]
# ## Caveats

# %%
display(load('multi_map_excluded_findings').head(50))
