# %% [markdown]
# # Stage 8.3 -- Mirage Regression Gate

# %%
from pathlib import Path
import pandas as pd
BASE = Path('../data/gold/validation/mirage_regression_gate')
def load(name):
    return pd.read_parquet(BASE / f'{name}.parquet')
summary = load('mirage_regression_summary')
datasets = load('mirage_dataset_comparison')
schema = load('mirage_schema_comparison')
features = load('mirage_feature_value_comparison')
region = load('mirage_region_timeline_comparison')
round_state = load('mirage_round_state_comparison')
side = load('mirage_side_dataset_comparison')
candidate = load('mirage_candidate_input_compatibility')
invariants = load('mirage_invariant_checks')
failures = load('mirage_regression_failures')
audit = load('mirage_regression_audit')

# %% [markdown]
# ## Regression Summary

# %%
display(summary)

# %% [markdown]
# ## Dataset Comparison

# %%
display(datasets)

# %% [markdown]
# ## Schema Differences

# %%
display(schema[schema['status'] != 'ok'])

# %% [markdown]
# ## Feature Value Differences

# %%
display(features[features['status'] != 'ok'])

# %% [markdown]
# ## Candidate Features

# %%
display(candidate)

# %% [markdown]
# ## Region Timeline Comparison

# %%
display(region)

# %% [markdown]
# ## Round State Comparison

# %%
display(round_state)

# %% [markdown]
# ## Side Datasets

# %%
display(side)

# %% [markdown]
# ## Invariants

# %%
display(invariants)

# %% [markdown]
# ## Failures

# %%
display(failures)

# %% [markdown]
# ## Audit

# %%
display(audit)

# %% [markdown]
# Next: onboard the first new map only if ready_for_new_map_onboarding is true.
