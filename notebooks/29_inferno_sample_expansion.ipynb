# %% [markdown]
# # Inferno Sample Expansion

# %%
import pandas as pd
from pathlib import Path
base = Path('../data/gold/modeling/inferno_sample_expansion')

# %%
pd.read_parquet(base / 'inferno_sample_summary.parquet')

# %%
pd.read_parquet(base / 'inferno_sample_gap_analysis.parquet')

# %%
pd.read_parquet(base / 'inferno_modeling_readiness_scorecard.parquet')

# %%
pd.read_parquet(base / 'inferno_class_coverage.parquet')

# %%
pd.read_parquet(base / 'inferno_opponent_coverage.parquet')

# %%
pd.read_parquet(base / 'inferno_sample_concentration_audit.parquet')

# %%
pd.read_parquet(base / 'inferno_frozen_baseline_sample_comparison.parquet')

# %%
pd.read_parquet(base / 'inferno_sample_learning_curve.parquet')

# %%
pd.read_parquet(base / 'inferno_next_data_targets.parquet')

# %%
pd.read_parquet(base / 'inferno_sample_expansion_audit.parquet')
