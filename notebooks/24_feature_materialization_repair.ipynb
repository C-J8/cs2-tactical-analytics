# %% [markdown]
# # Stage 8.9.1 -- Feature Materialization Repair

# %%
from pathlib import Path
import pandas as pd
BASE = Path('../data/gold/validation/feature_materialization_repair')
def load(name):
    return pd.read_parquet(BASE / f'{name}.parquet')

# %% [markdown]
# ## Final Audit

# %%
display(load('feature_materialization_repair_final_audit'))

# %% [markdown]
# ## Utility Source Capability

# %%
display(load('utility_source_capability'))

# %% [markdown]
# ## Utility Event Reconstruction

# %%
display(load('utility_event_reconstruction_audit'))

# %% [markdown]
# ## Utility Type Feature Sanity

# %%
display(load('utility_type_feature_sanity'))

# %% [markdown]
# ## Score Before Round

# %%
display(load('score_before_round_audit'))

# %% [markdown]
# ## Quality Gate Recovery

# %%
display(load('quality_gate_recovery'))

# %% [markdown]
# ## Mirage Migration Diff

# %%
display(load('mirage_feature_migration_diff').head(50))
